# %%
print("Hello world")
# Out:
# Hello world

# %%
explorer_table_list =['adj_neo_tx',
        'adverse_event',
        'biomarker',
        'cancer_condition',
        'cancer_diagnosis',
        'cancer_indicator',
        'cancer_medication',
        'care_goal',
        'comorbid_condition',
        'disease_assessment',
        'disease_status',
        'document_metadata',
        'drug',
        'encounter',
        'evaluation_status',
        'imaging',
        'lot',
        'metastatic_sites',
        'non_cancer_medication',
        'observation_period',
        'patient',
        'patient_test',
        'patient_vitals',
        'radiation',
        'staging',
        'surgery',
        'tumor_exam'
        ]
commercails_tables_list = ['adj_neo_tx',
            'adverse_event',
            'biomarker',
            'cancer_condition',
            'cancer_diagnosis',
            'cancer_indicator',
            'cancer_medication',
            'care_goal',
            'claim',
            'claim_care_team',
            'claim_payer',
            'claim_payer_med_mapping',
            'claim_payment',
            'claim_procedure',
            'claim_provider_npi_summary',
            'comorbid_condition',
             'ctti_facility_contacts',
             'ctti_facility_investigators',
             'ctti_indication',
             'ctti_site_map',
             'ctti_sponsors',
             'ctti_studies',
             'ctti_url',
            'disease_assessment',
            'disease_status',
            #'diversity_prediction',
            'document_metadata',
            'drug',
            'encounter',
            'evaluation_status',
            'imaging',
            'lot',
            'metastatic_sites',
            'non_cancer_medication',
            'npi_specialization',
            'observation_period',
            'patient',
            'patient_sdoh',
            'patient_test',
            'patient_vitals',
            'payment',
            'pharmacy_claim_payment',
            'provider',
            'radiation',
            'site_affiliated',
            'site_networks',
            'site_org_network_map',
            'site_organizations',
            'site_patient_map',
            'site_patient_physician_map',
            'site_physician',
            'site_physician_map',
            'site_prediction',
            'site_recommender_features',
            'staging',
            'surgery',
            'tumor_exam',
            'visit_occurrence'
            ]

# %%
list[set(explorer_table_list).union(set(commercails_tables_list))
]
# Out:
# list[{'observation_period', 'claim_payer_med_mapping', 'ctti_facility_contacts', 'site_patient_map', 'site_physician_map', 'biomarker', 'disease_status', 'site_prediction', 'adverse_event', 'drug', 'pharmacy_claim_payment', 'claim', 'lot', 'claim_provider_npi_summary', 'claim_payment', 'comorbid_condition', 'payment', 'site_affiliated', 'patient_vitals', 'provider', 'ctti_facility_investigators', 'visit_occurrence', 'non_cancer_medication', 'tumor_exam', 'surgery', 'ctti_studies', 'metastatic_sites', 'care_goal', 'patient', 'document_metadata', 'site_recommender_features', 'cancer_diagnosis', 'cancer_indicator', 'site_networks', 'claim_procedure', 'cancer_medication', 'ctti_url', 'disease_assessment', 'site_org_network_map', 'imaging', 'claim_payer', 'npi_specialization', 'site_organizations', 'ctti_indication', 'site_physician', 'encounter', 'adj_neo_tx', 'claim_care_team', 'cancer_condition', 'radiation', 'evaluation_status', 'ctti_site_map', 'patient_test', 'ctti_sponsors', 'stagi
# ...
